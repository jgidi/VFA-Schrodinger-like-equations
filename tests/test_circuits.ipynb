# %%
import sys
sys.path.append('../')

# %%
from main import RY_ansatz, ZGR_ansatz
import pennylane as qml 
import pennylane.numpy as np 
import matplotlib.pyplot as plt

# %%
num_qubits = 4

# %%
RY = RY_ansatz( num_qubits )
num_layers  = 2
init_params = np.zeros( (num_layers, RY.num_params) )
RY.num_params
# Out:
# 4

# %%
qml.draw_mpl( RY.construct_circuit )(init_params)
# Out:
# (<Figure size 800x500 with 1 Axes>, <Axes: >)

# %%
ZGR = ZGR_ansatz( num_qubits )
init_params = np.zeros( ( 1, ZGR.num_params ) )
ZGR.num_params
# Out:
# 13

# %%
qml.draw_mpl( ZGR.construct_circuit )(init_params)
# Out:
# (<Figure size 2800x500 with 1 Axes>, <Axes: >)
