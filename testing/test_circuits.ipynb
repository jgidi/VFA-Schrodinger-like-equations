# %%
import sys
sys.path.append('../')

# %%
from main import RY_ansatz, ZGR_ansatz
import pennylane as qml 
import pennylane.numpy as np 
import matplotlib.pyplot as plt

# %%
num_qubits = 4 
num_layers  = 2

# %%
RY = RY_ansatz( num_qubits , num_layers)
init_params = np.zeros( (num_layers, num_qubits) )
RY.num_params
# Out:
# 8

# %%
qml.draw_mpl( RY.construct_circuit )(init_params)
# Out:
# (<Figure size 900x500 with 1 Axes>, <Axes: >)

# %%
ZGR = ZGR_ansatz( num_qubits )
init_params = np.zeros( ( 1, ZGR.num_params ) )
ZGR.num_params
# Out:
# 15

# %%
qml.draw_mpl( ZGR.construct_circuit )(init_params)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 qml.draw_mpl( ZGR.construct_circuit )(init_params)
#
# File ~/.virtualenvs/qhack/lib/python3.11/site-packages/pennylane/drawer/draw.py:540, in draw_mpl.<locals>.wrapper(*args, **kwargs)
#     538 @wraps(qnode)
#     539 def wrapper(*args, **kwargs):
# --> 540     tape = qml.tape.make_qscript(qnode)(*args, **kwargs)
#     541     _wire_order = wire_order or tape.wires
#     543     return tape_mpl(
#     544         tape,
#     545         wire_order=_wire_order,
#    (...)
#     550         **kwargs,
#     551     )
#
# File ~/.virtualenvs/qhack/lib/python3.11/site-packages/pennylane/tape/qscript.py:1261, in make_qscript.<locals>.wrapper(*args, **kwargs)
#    1259 def wrapper(*args, **kwargs):
#    1260     with AnnotatedQueue() as q:
# -> 1261         fn(*args, **kwargs)
# ...
