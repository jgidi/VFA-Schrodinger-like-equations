# %%
import sys 
sys.path.append('../')

# %%
from main import Fourier_ansatz
import pennylane as qml 
import pennylane.numpy as np 
import matplotlib.pyplot as plt

# %%
num_qubits = 3

# %%
FA = Fourier_ansatz( num_qubits )
init_params = np.zeros( FA.num_params )
FA.num_params
# Out:
# 6

# %%
qml.draw_mpl( FA.construct_circuit )(init_params)
# Out:
# (<Figure size 900x400 with 1 Axes>, <Axes: >)
